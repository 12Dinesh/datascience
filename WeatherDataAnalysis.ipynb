# %% [markdown]
# Analysing Real world Weather Data

# %%
import pandas as pd
import os
os.getcwd()
# Out:
# 'C:\\Users\\MY PC\\Desktop\\DATA SCIENCE\\real_world_project'

# %%
data=pd.read_csv('C:\\Users\\MY PC\Desktop\\DATA SCIENCE\\real_world_project\\POWER_Point_Hourly_20010101_20210331_027d4709N_077d6887E_LST (2).csv')

# %%
data
# Out:
#         YEAR  MO  DY  HR  CLRSKY_SFC_SW_DWN  ALLSKY_KT  ALLSKY_SFC_UV_INDEX  \
# 0       2001   1   1   0                0.0     -999.0                  0.0
# 1       2001   1   1   1                0.0     -999.0                  0.0
# 2       2001   1   1   2                0.0     -999.0                  0.0
# 3       2001   1   1   3                0.0     -999.0                  0.0
# 4       2001   1   1   4                0.0     -999.0                  0.0
# ...      ...  ..  ..  ..                ...        ...                  ...
# 177475  2021   3  31  19                0.0     -999.0                  0.0
# 177476  2021   3  31  20                0.0     -999.0                  0.0
# 177477  2021   3  31  21                0.0     -999.0                  0.0
# 177478  2021   3  31  22                0.0     -999.0                  0.0
# 177479  2021   3  31  23                0.0     -999.0                  0.0
#
# ...

# %%
data.rename(columns={'DY':'DAY','HR':'HOURS'})
# Out:
#         YEAR  MO  DAY  HOURS  CLRSKY_SFC_SW_DWN  ALLSKY_KT  \
# 0       2001   1    1      0                0.0     -999.0
# 1       2001   1    1      1                0.0     -999.0
# 2       2001   1    1      2                0.0     -999.0
# 3       2001   1    1      3                0.0     -999.0
# 4       2001   1    1      4                0.0     -999.0
# ...      ...  ..  ...    ...                ...        ...
# 177475  2021   3   31     19                0.0     -999.0
# 177476  2021   3   31     20                0.0     -999.0
# 177477  2021   3   31     21                0.0     -999.0
# 177478  2021   3   31     22                0.0     -999.0
# 177479  2021   3   31     23                0.0     -999.0
#
#         ALLSKY_SFC_UV_INDEX    T2M  T2MDEW  T2MWET  QV2M   RH2M  PRECTOTCORR  \
# 0                       0.0  12.78    4.84    8.81  5.43  58.38         0.01
# 1                       0.0  12.35    4.96    8.65  5.49  60.50         0.01
# ...

# %%
data['CLRSKY_SFC_SW_DWN'].isnull().sum()
# Out:
# 0

# %%
data.WS10M.mean()
# Out:
# 2.878919990984957

# %%
data.WS50M.mean()
# Out:
# 4.319224419653002

# %%
data.PS.mean()
# Out:
# 98.66995762902836

# %%
data.PS.std()
# Out:
# 0.712395277716507

# %%
data.RH2M.var()
# Out:
# 577.6611872536097

# %%
data.QV2M.var()
# Out:
# 37.29774357108447

# %%
data.YEAR.value_counts()
# Out:
# 2020    8784
# 2004    8784
# 2008    8784
# 2016    8784
# 2012    8784
# 2001    8760
# 2013    8760
# 2019    8760
# 2018    8760
# 2017    8760
# 2015    8760
# 2014    8760
# 2011    8760
# 2002    8760
# 2010    8760
# 2009    8760
# 2007    8760
# 2006    8760
# 2005    8760
# 2003    8760
# 2021    2160
# Name: YEAR, dtype: int64

# %%
data.YEAR==2021]
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 177475     True
# 177476     True
# 177477     True
# 177478     True
# 177479     True
# Name: YEAR, Length: 177480, dtype: bool

# %%
data.ALLSKY_SFC_UV_INDEX.
# Out:
# dtype('float64')

# %%
data.groupby('YEAR').mean()
# Out:
#             MO         DY    HR  CLRSKY_SFC_SW_DWN   ALLSKY_KT  \
# YEAR
# 2001  6.526027  15.720548  11.5         237.044903 -482.014538
# 2002  6.526027  15.720548  11.5         233.816611 -481.900785
# 2003  6.526027  15.720548  11.5         232.177866 -481.689055
# 2004  6.513661  15.756831  11.5         234.344727 -482.065907
# 2005  6.526027  15.720548  11.5         238.446216 -481.900788
# 2006  6.526027  15.720548  11.5         235.607920 -481.901395
# 2007  6.526027  15.720548  11.5         233.963838 -481.676900
# 2008  6.513661  15.756831  11.5         230.164146 -481.847802
# 2009  6.526027  15.720548  11.5         235.380458 -481.786061
# 2010  6.526027  15.720548  11.5         230.533939 -481.915934
# 2011  6.526027  15.720548  11.5         231.788358 -481.679453
# 2012  6.513661  15.756831  11.5         232.025954 -481.844469
# 2013  6.526027  15.720548  11.5         234.839759 -481.794543
# 2014  6.526027  15.720548  11.5         232.859707 -482.023590
# ...

# %%
data.groupby('YEAR').min()
# Out:
#       MO  DY  HR  CLRSKY_SFC_SW_DWN  ALLSKY_KT  ALLSKY_SFC_UV_INDEX   T2M  \
# YEAR
# 2001   1   1   0                0.0     -999.0               -999.0  3.71
# 2002   1   1   0                0.0     -999.0               -999.0  2.44
# 2003   1   1   0                0.0     -999.0               -999.0  3.31
# 2004   1   1   0                0.0     -999.0               -999.0  4.44
# 2005   1   1   0                0.0     -999.0               -999.0  4.31
# 2006   1   1   0                0.0     -999.0               -999.0  2.32
# 2007   1   1   0                0.0     -999.0               -999.0  2.71
# 2008   1   1   0                0.0     -999.0               -999.0  2.66
# 2009   1   1   0                0.0     -999.0               -999.0  5.15
# 2010   1   1   0                0.0     -999.0               -999.0  4.03
# 2011   1   1   0                0.0     -999.0               -999.0  0.12
# 2012   1   1   0                0.0     -999.0               -999.0  0.99
# ...

# %%
data.groupby('YEAR').max()
# Out:
#       MO  DY  HR  CLRSKY_SFC_SW_DWN  ALLSKY_KT  ALLSKY_SFC_UV_INDEX    T2M  \
# YEAR
# 2001  12  31  23            1020.52       0.80                10.55  48.28
# 2002  12  31  23            1034.38       0.80                11.00  48.08
# 2003  12  31  23            1029.27       0.80                11.42  48.15
# 2004  12  31  23            1014.70       0.80                11.00  47.03
# 2005  12  31  23            1040.12       0.80                10.60  47.82
# 2006  12  31  23            1006.58       0.80                11.40  47.32
# 2007  12  31  23            1008.70       0.80                11.12  48.23
# 2008  12  31  23            1026.23       0.80                10.45  45.33
# 2009  12  31  23            1017.27       0.79                10.62  47.14
# 2010  12  31  23            1035.12       0.79                10.27  48.54
# 2011  12  31  23            1011.67       0.79                10.67  47.38
# ...

# %% [markdown]
# Data with temp >40 and Relative humidity>60

# %%
data[(data.T2M>40)|(data.RH2M>60)]
# Out:
#         YEAR  MO  DY  HR  CLRSKY_SFC_SW_DWN  ALLSKY_KT  ALLSKY_SFC_UV_INDEX  \
# 1       2001   1   1   1               0.00    -999.00                 0.00
# 2       2001   1   1   2               0.00    -999.00                 0.00
# 3       2001   1   1   3               0.00    -999.00                 0.00
# 4       2001   1   1   4               0.00    -999.00                 0.00
# 5       2001   1   1   5               0.00    -999.00                 0.00
# ...      ...  ..  ..  ..                ...        ...                  ...
# 177424  2021   3  29  16             267.67       0.58                 0.62
# 177443  2021   3  30  11             924.60       0.73                 8.55
# 177444  2021   3  30  12             919.25       0.73                 8.33
# 177445  2021   3  30  13             831.77       0.73                 6.58
# 177446  2021   3  30  14             666.58       0.68                 4.10
#
# ...

# %%
data['ALLSKY_KT'].apply(lambda x:pow(x,2))
# Out:
# 0         998001.0
# 1         998001.0
# 2         998001.0
# 3         998001.0
# 4         998001.0
#             ...
# 177475    998001.0
# 177476    998001.0
# 177477    998001.0
# 177478    998001.0
# 177479    998001.0
# Name: ALLSKY_KT, Length: 177480, dtype: float64

# %%
data.drop(columns=['ALLSKY_SFC_UV_INDEX','CLRSKY_SFC_SW_DWN','ALLSKY_KT'])
# Out:
#         YEAR  MO  DY  HR    T2M  T2MDEW  T2MWET  QV2M   RH2M  PRECTOTCORR  \
# 0       2001   1   1   0  12.78    4.84    8.81  5.43  58.38         0.01
# 1       2001   1   1   1  12.35    4.96    8.65  5.49  60.50         0.01
# 2       2001   1   1   2  11.97    5.07    8.51  5.49  62.50         0.01
# 3       2001   1   1   3  12.01    5.15    8.58  5.55  62.69         0.01
# 4       2001   1   1   4  11.95    5.33    8.64  5.62  63.69         0.02
# ...      ...  ..  ..  ..    ...     ...     ...   ...    ...          ...
# 177475  2021   3  31  19  27.34  -10.60    8.37  1.59   7.00         0.00
# 177476  2021   3  31  20  25.94  -10.74    7.59  1.59   7.50         0.00
# 177477  2021   3  31  21  24.52  -10.95    6.79  1.59   8.06         0.00
# 177478  2021   3  31  22  23.26  -11.30    5.98  1.53   8.44         0.00
# 177479  2021   3  31  23  22.14  -11.71    5.21  1.46   8.69         0.00
#
#            PS  WS10M   WD10M  WS50M   WD50M
# ...
